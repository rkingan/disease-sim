# %% [markdown]
# # Unlabeled plots of the karate and football graphs

# %%
import igraph
from dissim.igraph_util import load_graph_here

# %%
kg = load_graph_here("karate")
igraph.plot(kg, bbox=(400, 400), vertex_color="black", vertex_label=None, vertex_size=4)

# %%
fg = load_graph_here("football")
igraph.plot(fg, bbox=(400, 400), vertex_color="black", vertex_label=None, vertex_size=4)
